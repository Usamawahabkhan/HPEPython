# %% [markdown]
# ##### ========
# ## Lab

# %% [markdown]
# ##### ==================================================================================================
# ## Summary
#
# - Bar graphs compare values that are independant of each other.
# - Pie charts divide the whole entity into different proportional parts.
# - Line graphs show how a value can change over time.
# - Scatter plots show the collection of ordered pairs on a cartesian plane.
# - Histograms summarize data that are measured on an interval.
#
# ##### ==================================================================================================

# %% [markdown]
# ## Instructions
#
# Before starting with the exercises, make sure to import the necessary libraries. For plotting, we will use the `matplotlib` library. You can import it using the following code:
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# ```
#
# This will allow you to create various types of plots and visualizations as required in the exercises.

# %%
#import here
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ##### ==================================================================================================
# Now lets load in our dataset `cars4sale.csv` and call it `cars`. We want to now create a histogram of the dataset that shows the number of cars sold group by the year the car was manufactured.

# %%
cars_url = "https://raw.githubusercontent.com/freestackinitiative/COOP-PythonLessons/main/lessons/lesson4/data/cars4sale.csv"
cars = pd.read_csv(cars_url)
cars.head()
# Out:
#    Year    Make            Model Used/New  Price (USD)  ConsumerRating  \
# 0  2019  Toyota        Sienna SE     Used        39998             4.6
# 1  2018    Ford     F-150 Lariat     Used        49985             4.8
# 2  2017     RAM     1500 Laramie     Used        41860             4.7
# 3  2021   Honda  Accord Sport SE     Used        28500             5.0
# 4  2020   Lexus           RX 350     Used        49000             4.8
#
#    ConsumerReviews SellerType  \
# 0               45     Dealer
# 1              817     Dealer
# 2              495     Dealer
# 3               36     Dealer
# 4               76     Dealer
#
#                                           SellerName  SellerRating  ...  \
# 0  CarMax Murrieta - Now offering Curbside Pickup...           3.3  ...
# 1                                    Giant Chevrolet           4.8  ...
# 2                             Gill Auto Group Madera           4.6  ...
# ...

# %%
cars.columns
# Out:
# Index(['Year', 'Make', 'Model', 'Used/New', 'Price (USD)', 'ConsumerRating',
#        'ConsumerReviews', 'SellerType', 'SellerName', 'SellerRating',
#        'SellerReviews', 'StreetName', 'State', 'Zipcode', 'DealType',
#        'ComfortRating', 'InteriorDesignRating', 'PerformanceRating',
#        'ValueForMoneyRating', 'ExteriorStylingRating', 'ReliabilityRating',
#        'ExteriorColor', 'InteriorColor', 'Drivetrain', 'MinMPG', 'MaxMPG',
#        'FuelType', 'Transmission', 'Engine', 'VIN', 'Stock#', 'Mileage'],
#       dtype='object')

# %%
plt.title("Number of Cars (by Year Manufactured) being Sold")
plt.ylabel("Number of Cars")
plt.xlabel("Year Manufactured")

plt.hist(cars.loc[:,'Year'], bins = list(range(2000,2022)), color = "r", edgecolor = 'black')
plt.grid()
plt.show()

# %% [markdown]
# ### Exercise 1:
# Create a scatter plot using the `cars` dataset with `Mileage` being the x-axis and `Price (USD)` being the y-axis. Be sure to give the plot the title of `Mileage vs 'Price (USD)` and properly label the x and y axis with `Mileage` and `Price (USD)` respectively.

# %%
# Write your code here
"""
This script performs the following tasks:
1. Reads the data from the specified URL.
2. Plots a histogram of the number of cars being sold by year manufactured.
3. Sets the title of the plot to "Number of Cars (by Year Manufactured) being Sold".
4. Sets the x-axis label to "Year Manufactured".
5. Sets the y-axis label to "Number of Cars".
6. Sets the color of the bars to red.
7. Sets the edge color of the bars to black.
8. Displays the plot.
9. Runs the code to generate the expected output: a histogram of the number of cars being sold by year manufactured with appropriate labels and colors.
"""
 
plt.scatter(cars['Mileage'], cars['Price (USD)'])
plt.title("Mileage vs Price (USD)")
plt.xlabel("Mileage")
plt.ylabel("Price (USD)")
plt.grid(True)
plt.show()
# Expected output: A histogram of the number of cars being sold by year manufactured
# The x-axis label should be "Year Manufactured"

# %% [markdown]
# ##### ==================================================================================================
# ### Exercise 2:
# Create a pie chart using the `cars` dataset to show the ratio of used cars vs new cars using the `Used/New` column of the dataset. Properly label the chart with a section for `Used` and `Manufacturer Certified`. Name the title `Used and Manufacturer Certified Cars for Sale`.

# %%
# Write your code here
"""
Generates a pie chart showing the distribution of used and manufacturer certified cars for sale.

The function performs the following steps:
1. Counts the occurrences of each category in the 'Used/New' column of the `cars` DataFrame.
2. Creates a pie chart using the counts, with labels corresponding to the categories.
3. Displays the percentage of each category on the pie chart.
4. Sets the title of the pie chart to 'Used and Manufacturer Certified Cars for Sale'.
5. Displays the pie chart.

Parameters:
- cars (DataFrame): A pandas DataFrame containing a column 'Used/New' with categorical data indicating whether a car is used or manufacturer certified.

Returns:
- None
"""
used_new_counts = cars['Used/New'].value_counts()
plt.pie(used_new_counts, labels=used_new_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Used and Manufacturer Certified Cars for Sale')
plt.show()

# %% [markdown]
# ##### ==================================================================================================
# ### Exercise 3:
#
# Create a bar graph using the `cars` dataset to show the number of cars sorted by their drivetrain type by using `Drivetrain Type`. Be sure to label the x and y axis with `Frequency` and `Drivetrain Type` respectively. Name the title `Number of Drivetrain Types`.

# %%
# Write your code here
"""
This script generates a bar plot to visualize the frequency of different drivetrain types in a dataset.

Steps:
1. Calculate the frequency of each drivetrain type using the `value_counts` method.
2. Plot the frequencies as a bar chart with the following customizations:
    - Bar color: skyblue
    - Bar edge color: black
3. Add a title to the plot: 'Number of Drivetrain Types'
4. Label the x-axis as 'Drivetrain Type'
5. Label the y-axis as 'Frequency'
6. Add a grid to the y-axis for better readability.
7. Display the plot.

Dependencies:
- pandas as pd
- matplotlib.pyplot as plt

Assumptions:
- The dataset `cars` is a pandas DataFrame that contains a column named 'Drivetrain Type'.
"""
drivetrain_counts = cars['Drivetrain'].value_counts()
drivetrain_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Number of Drivetrain Types')
plt.xlabel('Drivetrain Type')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ##### ==================================================================================================
# ### Exercise 4:
#
# Create a histogram using the `mcdonalds` dataset to show the frequency of items on the mcdonalds menu categorized by their calorie range using `Calories`. Be sure to label the x and y axis as `Calories` and `Frequency` respectively. Name the title `Number of McDonalds Menu Items by Calories`.

# %%
# Write your code here
"""
This script fetches McDonald's menu data from a given URL and plots a histogram of the calorie content of the menu items.
Steps:
1. Reads the McDonald's menu data from a CSV file located at the specified URL.
2. Plots a histogram of the 'Calories' column from the dataset.
    - The histogram has 20 bins.
    - The bars are colored blue with black edges.
3. Adds a title, x-axis label, y-axis label, and grid lines to the plot.
4. Displays the plot.
Dependencies:
- pandas as pd
- matplotlib.pyplot as plt
"""
mcdonalds_url = "https://raw.githubusercontent.com/freestackinitiative/COOP-PythonLessons/main/lessons/lesson4/data/mcdonalds.csv"
mcdonalds = pd.read_csv(mcdonalds_url)

plt.hist(mcdonalds['Calories'], bins=20, color='blue', edgecolor='black')
plt.title('Number of McDonalds Menu Items by Calories')
plt.xlabel('Calories')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ##### ==================================================================================================
# ### Exercise 5:
#
# Load in the `target.csv` dataset and call it `target`. Then create a line graph using the 2019-2022 Target Corporation's closing stock prices using the `target` dataset where `Close` represents the closing stock price for that specific date and `Date` to represent the date. Be sure to label your x and y axis as `Data` and `Dollar (USD)` respectively. Name the title `Target Corporation Stocks 2019-2022`.

# %%
# Write your code here
target_url = "https://raw.githubusercontent.com/freestackinitiative/COOP-PythonLessons/main/lessons/lesson4/data/target.csv"

target = pd.read_csv(target_url)
target['Date'] = pd.to_datetime(target['Date'])

plt.plot(target['Date'], target['Close'])
plt.title('Target Corporation Stocks 2019-2022')
plt.xlabel('Date')
plt.ylabel('Dollar (USD)')
plt.grid(True)
plt.show()
